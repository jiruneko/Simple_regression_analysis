# %% [markdown]
# <a href="https://colab.research.google.com/github/jiruneko/Simple_regression_analysis/blob/main/simple_regression_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample.csv')

x = df[['temperature']]
y = df[['Quantity']]

# %%
import matplotlib.pyplot as plt

plt.plot(x, y, 'o')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x, y)

a = model.coef_
b = model.intercept_

print("回帰係数　：　%.2f" %a)
print("切片　：　%.2f" %b)
print("モデル式　：　y = %.2fx + %.2f" %(a, b))
# Out:
# 回帰係数　：　1.07
# 切片　：　6.75
# モデル式　：　y = 1.07x + 6.75

# %%
plt.plot(x, y, 'o')
plt.plot(x, model.predict(x))
plt.show()

# %%
print("決定係数 : %.2f" %model.score(x, y))
# Out:
# 決定係数 : 0.57
